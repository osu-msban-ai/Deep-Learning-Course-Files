# %%
aug_gen = image.ImageDataGenerator(rotation_range=10.0, width_shift_range=0.1, height_shift_range=0.1, 
                             shear_range=0.15, zoom_range=0.1, channel_shift_range=10.0, 
                             fill_mode='nearest', cval=0.0, horizontal_flip=True, vertical_flip=False)

# %%
image_path = data_path+'sample/train/cats/cat.10074.jpg'

# %%
image = np.expand_dims(plt.imread(image_path), 0)
plt.imshow(image[0])

# %%
aug_iter = aug_gen.flow(image)

# %%
aug_images = [next(aug_iter)[0].astype(np.uint8) for i in range(10)]

# %%
plots(aug_images, figsize=(20, 7), rows=2)
